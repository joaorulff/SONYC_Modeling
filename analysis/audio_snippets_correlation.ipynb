# %%
import pandas as pd

# %% [markdown]
# ### Reading weather dataset

# %%
precipitation = pd.read_pickle('../data/weather/precipitation.pkl')

# %% [markdown]
# ### Plotting precipitation

# %%
precipitation['2018-02-01':'2018-03-01'].plot(figsize=(20,5))

# %%
precipitation['2018-02-05':'2018-02-06'].plot(figsize=(20,5))
